# %% [markdown]
# # Splines cúbicos

# %%
def Spline(x: float, x0: float, pars: dict[str, float]) -> float:
    a = pars["a"]
    b = pars["b"]
    c = pars["c"]
    d = pars["d"]
    return a + b * (x - x0) + c * (x - x0) ** 2 + d * (x - x0) ** 3

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = [-1, 0, 1]
ys = [1, 5, 3]
s = [
    {"a": 1, "b": 5.5, "c": 0, "d": -1.5},
    {"a": 5, "b": 1, "c": -4.5, "d": 1.5},
]
for i, x_i in enumerate(xs[:-1]):
    _x = np.linspace(x_i, xs[i + 1], 20)
    _y = Spline(_x, x_i, s[i])
    plt.plot(_x, _y, color="red")

plt.scatter(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con splines cúbicos")
plt.show()

# %% [markdown]
# # Tarea
# * Grafique los splines cúbicos tal que cumplan con una pendiente de $m=-3$ en los puntos dados.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Nodos y pendiente deseada
x0, y0 = -1, 1
x1, y1 =  0, 5
x2, y2 =  1, 3
m = -3

# 2) Coeficientes (hallados analíticamente)
a0, b0, c0, d0 = 1,  7.5,  0,  -3.5
a1, b1, c1, d1 = 5, -3.0, 1.5, -0.5

# 3) Definir funciones spline
def S0(x):
    return a0 + b0*(x - x0) + c0*(x - x0)**2 + d0*(x - x0)**3

def S1(x):
    return a1 + b1*(x - x1) + c1*(x - x1)**2 + d1*(x - x1)**3

# 4) Graficar
xs0 = np.linspace(x0, x1, 100)
xs1 = np.linspace(x1, x2, 100)

plt.figure()
plt.plot(xs0, S0(xs0), 'C0', label='S0 en [−1,0]')
plt.plot(xs1, S1(xs1), 'C1', label='S1 en [0,1]')
plt.scatter([x0, x1, x2], [y0, y1, y2], color='k', zorder=5)

# línea de pendiente m en x1
x_line = np.linspace(x1-0.5, x1+0.5, 10)
y_line = y1 + m*(x_line - x1)
plt.plot(x_line, y_line, 'k--', label=f'Pendiente m={m}')

plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Spline clamped con pendiente m en x₁')
plt.grid(True)
plt.show()

# %%
# Código actualizado: define splines, muestra respuestas e imprime resultados

import numpy as np
import matplotlib.pyplot as plt

# 1) Nodos y pendiente deseada
x0, y0 = -1, 1
x1, y1 =  0, 5
x2, y2 =  1, 3
m = -3

# 2) Coeficientes (hallados analíticamente)
a0, b0, c0, d0 = 1,  7.5,  0,  -3.5
a1, b1, c1, d1 = 5, -3.0, 1.5, -0.5

# 3) Imprimir las expresiones de los splines
print("Expresión de S0(x):")
print(f"S0(x) = {a0} + {b0}*(x - ({x0})) + {c0}*(x - ({x0}))**2 + {d0}*(x - ({x0}))**3")
print("\nExpresión de S1(x):")
print(f"S1(x) = {a1} + {b1}*(x - ({x1})) + {c1}*(x - ({x1}))**2 + {d1}*(x - ({x1}))**3")

# 4) Definir funciones spline
def S0(x):
    return a0 + b0*(x - x0) + c0*(x - x0)**2 + d0*(x - x0)**3

def S1(x):
    return a1 + b1*(x - x1) + c1*(x - x1)**2 + d1*(x - x1)**3

# 5) Graficar
xs0 = np.linspace(x0, x1, 100)
xs1 = np.linspace(x1, x2, 100)

plt.figure()
plt.plot(xs0, S0(xs0), 'C0', label='S0 en [−1,0]')
plt.plot(xs1, S1(xs1), 'C1', label='S1 en [0,1]')
plt.scatter([x0, x1, x2], [y0, y1, y2], color='k', zorder=5)

# línea de pendiente m en x1
x_line = np.linspace(x1-0.5, x1+0.5, 10)
y_line = y1 + m*(x_line - x1)
plt.plot(x_line, y_line, 'k--', label=f'Pendiente m={m}')

plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Spline clamped con pendiente m en x₁')
plt.grid(True)
plt.show()
# Out:
# Expresión de S0(x):
# S0(x) = 1 + 7.5*(x - (-1)) + 0*(x - (-1))**2 + -3.5*(x - (-1))**3
#
# Expresión de S1(x):
# S1(x) = 5 + -3.0*(x - (0)) + 1.5*(x - (0))**2 + -0.5*(x - (0))**3
